# %% [markdown]
# # Домашнее задание "Продвинутая линейная алгебра".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Дан объект в $2D$ пространстве

# %%
import numpy as np
import matplotlib.pyplot as plt

A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# При помощи линейных отображений:
# - Уменьшить объект в два раза
# - Повернуть на 130 градусов
# - Отразить объект относительно прямой y=x (поможет матрица `[[0, 1, 0], [1, 0, 0], [0, 0, 1]]`)

# %% [markdown]
# Уменьшаем

# %%
a = np.array([[0.5,0,0],[0,0.5,0],[0,0,0.5]])
A = np.array(A@a)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# Применяем диагональную матрицу в качестве линейного оператора со значениями 0,5 на главной диагонали, что знаменует уменьшение по каждой координате в два раза

# %% [markdown]
# Поворачиваем

# %%
from math import cos, sin, radians
phi = radians(130)
phi
# Out:
# 2.2689280275926285

# %%
a = np.array([[cos(phi), -sin(phi),0],[sin(phi), cos(phi),0],[0,0,1]])
a
# Out:
# array([[-0.64278761, -0.76604444,  0.        ],
#        [ 0.76604444, -0.64278761,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %% [markdown]
# Ну раз уж мы имеем пространство предположу, что у нас есть ось Z получается, поэтому вот такая вот матрица

# %%
A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A@a)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# Не могу представить как отразить относитенльо y=x, поэтому наверное не зачет здесь.

# %%
a = np.array([[0,1,0],[1,0,0],[0,0,-1]])

# %%
A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A@a)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Найдите спектральное разложение матрицы:
# ```
# m = np.array([[1, 2],
#               [2, 3]])
# print(m)
# ```

# %%
m = np.array([[1,2],[2,3]])
m
# Out:
# array([[1, 2],
#        [2, 3]])

# %% [markdown]
# Делаем заключение, что матрица симметрична, значит можно спектрально разложить
#
# $A = S ⋅ D ⋅ S^T$

# %%
eigv = np.linalg.eig(m)
val1 = eigv[0][0]
val2 = eigv[0][1]
vector1 = eigv[1][0]
vector2 = eigv[1][1]

# %%
eigv
# Out:
# (array([-0.23606798,  4.23606798]),
#  array([[-0.85065081, -0.52573111],
#         [ 0.52573111, -0.85065081]]))

# %%
vector1
# Out:
# array([-0.85065081, -0.52573111])

# %%
S = np.array([vector1,vector2]).T
S
# Out:
# array([[-0.85065081,  0.52573111],
#        [-0.52573111, -0.85065081]])

# %%
D = np.array([[val1,0],[0,val2]])
D
# Out:
# array([[-0.23606798,  0.        ],
#        [ 0.        ,  4.23606798]])

# %%
answer = S@D@S.T
answer
# Out:
# array([[ 1., -2.],
#        [-2.,  3.]])

# %% [markdown]
# К сожалению сложно пока понять интуицию того, что я сделал поэтому не могу оценить правильность результата. Спасибо за првоерку - с удовольствием проведу работу над ошибками
